# %%
# Definir los tipos de comida y bebidas
comidas = ["Pizza", "Hamburguesa", "Sándwich", "Ensalada", "Pasta"]
bebidas = ["Café", "Té", "Refresco"]

# Inicializar lista de pedidos
pedidos = []

# Función para capturar alumnos de manera recursiva
def capturar_alumno():
    # Solicitar nombre del alumno
    nombre = input("Ingrese el nombre del alumno (o 'q' para salir): ")

    if nombre != 'q':
        pedidos_alumno = {}

        # Mostrar tipos de comida disponibles
        print("Tipos de comida disponibles:")
        for i, comida in enumerate(comidas, start=1):
            print(f"{i}. {comida}")
        comida_elegida = int(input("Elija el número de la comida que desea: "))
        pedidos_alumno["Comida"] = comidas[comida_elegida - 1]

        # Mostrar tipos de bebida disponibles
        print("Tipos de bebida disponibles:")
        for i, bebida in enumerate(bebidas, start=1):
            print(f"{i}. {bebida}")
        bebida_elegida = int(input("Elija el número de la bebida que desea: "))
        pedidos_alumno["Bebida"] = bebidas[bebida_elegida - 1]

        # Agregar el pedido a la lista de pedidos
        pedidos.append((nombre, pedidos_alumno))

        # Llamada recursiva para capturar más alumnos
        capturar_alumno()

        # Ordenar la lista de pedidos por nombre
    ordenar_pedidos = sorted(pedidos, key=lambda x: x[0])

    print("\nLista de nombres de alumnos ordenados:")
    for i, (nombre, _) in enumerate(ordenar_pedidos, start=1):
        print(f"{i}. Nombre: {nombre}")

# Menú de opciones
while True:
    print("\n--- Menú ---")
    print("1. Capturar Alumno")
    print("2. Generar Pedidos")
    print("3. Imprimir Resultados")
    print("4. Ordenar Pedidos por Nombre")
    print("5. Salir")

    opcion = input("Seleccione una opción: ")

    if opcion == '1':
        capturar_alumno()
    elif opcion == '2':
        generar_pedidos()
    elif opcion == '3':
        imprimir_resultados()
    elif opcion == '4':
        ordenar_pedidos()
    elif opcion == '5':
        break
    else:
        print("Opción no válida. Intente de nuevo.")
# Out:
# --- Menú ---
# 1. Capturar Alumno
# 2. Generar Pedidos
# 3. Imprimir Resultados
# 4. Ordenar Pedidos por Nombre
# 5. Salir
# Seleccione una opción: 1
# Ingrese el nombre del alumno (o 'q' para salir): miguel
# Tipos de comida disponibles:
# 1. Pizza
# 2. Hamburguesa
# 3. Sándwich
# 4. Ensalada
# 5. Pasta
# Elija el número de la comida que desea: 3
# Tipos de bebida disponibles:
# 1. Café
# 2. Té
# 3. Refresco
# Elija el número de la bebida que desea: 2
# Ingrese el nombre del alumno (o 'q' para salir): daniel
# Tipos de comida disponibles:
# 1. Pizza
# 2. Hamburguesa
# 3. Sándwich
# 4. Ensalada
# 5. Pasta
# Elija el número de la comida que desea: 4
# Tipos de bebida disponibles:
# 1. Café
# 2. Té
# 3. Refresco
# Elija el número de la bebida que desea: 2
# Ingrese el nombre del alumno (o 'q' para salir): cesar
# Tipos de comida disponibles:
# 1. Pizza
# 2. Hamburguesa
# 3. Sándwich
# 4. Ensalada
# 5. Pasta
# Elija el número de la comida que desea: 2
# Tipos de bebida disponibles:
# 1. Café
# 2. Té
# 3. Refresco
# Elija el número de la bebida que desea: 3
# Ingrese el nombre del alumno (o 'q' para salir): q
#
# Lista de nombres de alumnos ordenados:
# 1. Nombre: cesar
# 2. Nombre: daniel
# 3. Nombre: miguel
#
# Lista de nombres de alumnos ordenados:
# 1. Nombre: cesar
# 2. Nombre: daniel
# 3. Nombre: miguel
#
# Lista de nombres de alumnos ordenados:
# 1. Nombre: cesar
# 2. Nombre: daniel
# 3. Nombre: miguel
#
# Lista de nombres de alumnos ordenados:
# 1. Nombre: cesar
# 2. Nombre: daniel
# 3. Nombre: miguel
#
# --- Menú ---
# 1. Capturar Alumno
# 2. Generar Pedidos
# 3. Imprimir Resultados
# 4. Ordenar Pedidos por Nombre
# 5. Salir
# Seleccione una opción: 3
# Alumno 1: miguel, Comida: Sándwich, Bebida: Té
# Alumno 2: daniel, Comida: Ensalada, Bebida: Té
# Alumno 3: cesar, Comida: Hamburguesa, Bebida: Refresco
#
# --- Menú ---
# 1. Capturar Alumno
# 2. Generar Pedidos
# 3. Imprimir Resultados
# 4. Ordenar Pedidos por Nombre
# 5. Salir
# Seleccione una opción: 5
